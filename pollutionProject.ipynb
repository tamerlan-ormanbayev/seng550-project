# %% [markdown]
# # SENG-550 Term Project
# ### ML Classifier for Air Quality in Dublin

# %%
#Importing PySpark Libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit, concat, when, split, mean, lower, trim
from pyspark.ml.evaluation import BinaryClassificationEvaluator 
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.feature import VectorAssembler

spark = SparkSession.builder.appName("PollutionClassification").getOrCreate()

file_path = "dublin-city-council-co-2011p20110929-1048.csv"

# %%
from pyspark.sql.types import StructType, StructField, StringType

# Load the file and skip the first 5 rows
rdd = sc.textFile(file_path).zipWithIndex() \
    .filter(lambda line_num: line_num[1] >= 7) \
    .map(lambda line_num: line_num[0])

# Extract the header and data
header = rdd.first()  # Fetch the first row as the header
data_rdd = rdd.filter(lambda row: row != header)  # Exclude header from data rows

# Define the column names from the header
columns = header.split(",")

# Split data rows by commas and trim whitespace
data_split_rdd = data_rdd.map(lambda row: [x.strip() for x in row.split(",")])

# Filter rows to ensure the correct number of columns
data_split_rdd = data_split_rdd.filter(lambda row: len(row) == len(columns))

# Define schema
schema = StructType([
    StructField("Date", StringType(), True),
    StructField("Time", StringType(), True),
    StructField("Wood_CO_mg_m3", StringType(), True),
    StructField("Wood_8hr_avg", StringType(), True),
    StructField("Wood_Flag", StringType(), True),
    StructField("Wood_Comment", StringType(), True),
    StructField("Col_CO_mg_m3", StringType(), True),
    StructField("Col_8hr_avg", StringType(), True),
    StructField("Col_Flag", StringType(), True),
    StructField("Col_Comment", StringType(), True),
])

# Convert RDD to DataFrame
data = spark.createDataFrame(data_split_rdd, schema=schema)

# Create a list of values to be replaced with NULL
special_values = ['#DIV/0!', 'cal', 'CAL', 'no data', 'No data', 'ext cal', 'SERVICE', 'Cal', 'Zero Air', 'Service', '']

def replace_special_values(column_name):
    # Handle empty strings and whitespace explicitly
    condition = (
        when(trim(col(column_name)) == '', None)
        .when(lower(trim(col(column_name))).isin([v.lower() for v in special_values]), None)
    )
    return condition.otherwise(col(column_name))

# Apply the replacements to all columns
columns_to_clean = ['Wood_CO_mg_m3', 'Wood_8hr_avg', 'Col_CO_mg_m3', 'Col_8hr_avg']

for column in columns_to_clean:
    data = data.withColumn(column, replace_special_values(column))

# Show the DataFrame
data.show()
# Out:
# +----------+----+-------------+------------+---------+------------+------------+-----------+--------+-----------+
# |      Date|Time|Wood_CO_mg_m3|Wood_8hr_avg|Wood_Flag|Wood_Comment|Col_CO_mg_m3|Col_8hr_avg|Col_Flag|Col_Comment|
# +----------+----+-------------+------------+---------+------------+------------+-----------+--------+-----------+
# |31/12/2010|  18|         NULL|        NULL|         |            |        NULL|       NULL|        |           |
# |31/12/2010|  19|         NULL|        NULL|         |            |        NULL|       NULL|        |           |
# |31/12/2010|  20|         NULL|        NULL|         |            |        NULL|       NULL|        |           |
# |31/12/2010|  21|         NULL|        NULL|         |            |        NULL|       NULL|        |           |
# |31/12/2010|  22|         NULL|        NULL|         |            |        NULL|       NULL|        |           |
# |31/12/2010|  23|         NULL|        NULL|         |            |        NULL|       NULL|        |           |
# |01/01/2011|   0|         NULL|         0.2|         |            |        NULL|       NULL|        |           |
# |01/01/2011|   1|          0.2|         0.1|        2|            |         0.5|        0.5|       2|           |
# |01/01/2011|   2|          0.1|         0.1|        2|            |         0.6|        0.5|       2|           |
# |01/01/2011|   3|          0.1|         0.1|        2|            |         0.6|        0.6|       2|           |
# |01/01/2011|   4|          0.1|         0.1|        2|            |         0.5|        0.5|       2|           |
# |01/01/2011|   5|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |
# |01/01/2011|   6|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |
# |01/01/2011|   7|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |
# |01/01/2011|   8|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |
# |01/01/2011|   9|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |
# |01/01/2011|  10|            0|         0.1|        2|            |         0.3|        0.4|       2|           |
# |01/01/2011|  11|            0|         0.1|        2|            |         0.3|        0.4|       2|           |
# |01/01/2011|  12|          0.1|         0.1|        2|            |         0.3|        0.3|       2|           |
# |01/01/2011|  13|            0|         0.1|        2|            |         0.3|        0.3|       2|           |
# +----------+----+-------------+------------+---------+------------+------------+-----------+--------+-----------+
# only showing top 20 rows

# %%
def classify_air_quality(col_val):
    if col_val is None:
        return "Unknown"
    col_val = float(col_val)
    if col_val <= 0.2:
        return "Low"
    elif col_val <= 0.4:
        return "Moderate"
    elif col_val <= 0.6:
        return "High"
    else:
        return "Very High"

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

# Define the UDF
classify_udf = udf(lambda val: classify_air_quality(val), StringType())

# Apply classification to Wood_8hr_avg and Col_8hr_avg
data = data.withColumn("Wood_Quality", classify_udf(col("Wood_8hr_avg"))) \
           .withColumn("Col_Quality", classify_udf(col("Col_8hr_avg")))

data.show(8700)
# Out:
# +----------+----+-------------+------------+---------+------------+------------+-----------+--------+-----------+------------+-----------+
# |      Date|Time|Wood_CO_mg_m3|Wood_8hr_avg|Wood_Flag|Wood_Comment|Col_CO_mg_m3|Col_8hr_avg|Col_Flag|Col_Comment|Wood_Quality|Col_Quality|
# +----------+----+-------------+------------+---------+------------+------------+-----------+--------+-----------+------------+-----------+
# |31/12/2010|  18|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |31/12/2010|  19|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |31/12/2010|  20|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |31/12/2010|  21|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |31/12/2010|  22|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |31/12/2010|  23|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |01/01/2011|   0|         NULL|         0.2|         |            |        NULL|       NULL|        |           |         Low|    Unknown|
# |01/01/2011|   1|          0.2|         0.1|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |01/01/2011|   2|          0.1|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |01/01/2011|   3|          0.1|         0.1|        2|            |         0.6|        0.6|       2|           |         Low|       High|
# |01/01/2011|   4|          0.1|         0.1|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |01/01/2011|   5|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |         Low|       High|
# |01/01/2011|   6|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |         Low|       High|
# |01/01/2011|   7|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |         Low|       High|
# |01/01/2011|   8|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |01/01/2011|   9|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |01/01/2011|  10|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |01/01/2011|  11|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |01/01/2011|  12|          0.1|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  13|            0|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  14|            0|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  15|            0|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  16|            0|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  17|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  18|          0.1|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  19|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  20|          0.1|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  21|          0.1|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  22|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |01/01/2011|  23|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   0|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   1|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   2|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   3|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   4|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   5|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   6|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|   7|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |02/01/2011|   8|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |02/01/2011|   9|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |02/01/2011|  10|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |02/01/2011|  11|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |02/01/2011|  12|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |02/01/2011|  13|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |02/01/2011|  14|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|  15|          0.1|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|  16|          0.1|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|  17|          0.1|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|  18|          0.1|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|  19|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|  20|          0.1|         0.1|        2|            |         0.5|        0.3|       2|           |         Low|   Moderate|
# |02/01/2011|  21|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |02/01/2011|  22|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |02/01/2011|  23|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   0|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   1|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   2|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   3|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   4|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   5|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   6|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|   7|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |03/01/2011|   8|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |03/01/2011|   9|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |03/01/2011|  10|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |03/01/2011|  11|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |03/01/2011|  12|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |03/01/2011|  13|          0.1|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |03/01/2011|  14|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |03/01/2011|  15|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |03/01/2011|  16|            0|           0|        2|            |         0.7|        0.3|       2|           |         Low|   Moderate|
# |03/01/2011|  17|          0.1|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|  18|          0.2|         0.1|        2|            |         0.8|        0.4|       2|           |         Low|   Moderate|
# |03/01/2011|  19|          0.3|         0.1|        2|            |         0.7|        0.5|       2|           |         Low|       High|
# |03/01/2011|  20|          0.3|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |03/01/2011|  21|          0.1|         0.1|        2|            |         0.4|        0.6|       2|           |         Low|       High|
# |03/01/2011|  22|            0|         0.1|        2|            |         0.3|        0.6|       2|           |         Low|       High|
# |03/01/2011|  23|            0|         0.1|        2|            |         0.2|        0.5|       2|           |         Low|       High|
# |04/01/2011|   0|            0|         0.1|        2|            |         0.2|        0.5|       2|           |         Low|       High|
# |04/01/2011|   1|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|   2|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|   3|            0|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |04/01/2011|   4|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |04/01/2011|   5|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |04/01/2011|   6|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |04/01/2011|   7|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |04/01/2011|   8|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |04/01/2011|   9|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |04/01/2011|  10|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |04/01/2011|  11|         NULL|           0|        0|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |04/01/2011|  12|         NULL|           0|        0|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |04/01/2011|  13|         NULL|           0|        0|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  14|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  15|            0|           0|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  16|          0.1|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  17|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  18|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  19|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  20|            0|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  21|            0|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  22|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |04/01/2011|  23|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|   0|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   1|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   2|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   3|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   4|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   5|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   6|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   7|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   8|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|   9|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|  10|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|  11|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|  12|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  13|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  14|            0|           0|        2|            |        NULL|        0.4|       0|           |         Low|   Moderate|
# |05/01/2011|  15|            0|           0|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  16|          0.1|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|  17|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |05/01/2011|  18|          0.2|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  19|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  20|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  21|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  22|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |05/01/2011|  23|          0.1|         0.1|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |06/01/2011|   0|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |         Low|       High|
# |06/01/2011|   1|          0.1|         0.1|        2|            |         0.4|        0.5|       2|           |         Low|       High|
# |06/01/2011|   2|          0.1|         0.1|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |06/01/2011|   3|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |06/01/2011|   4|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |06/01/2011|   5|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |06/01/2011|   6|          0.1|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|   7|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|   8|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|   9|          0.2|         0.1|        2|            |         0.5|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|  10|          0.2|         0.1|        2|            |         0.4|       NULL|       2|           |         Low|    Unknown|
# |06/01/2011|  11|          0.1|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|  12|          0.1|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|  13|          0.1|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|  14|            0|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |06/01/2011|  15|          0.1|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |06/01/2011|  16|          0.1|         0.1|        2|            |         0.9|        0.4|       2|           |         Low|   Moderate|
# |06/01/2011|  17|          0.3|         0.1|        2|            |         0.8|        0.5|       2|           |         Low|       High|
# |06/01/2011|  18|          0.3|         0.1|        2|            |         0.8|        0.5|       2|           |         Low|       High|
# |06/01/2011|  19|          0.3|         0.2|        2|            |         1.2|        0.6|       2|           |         Low|       High|
# |06/01/2011|  20|          0.3|         0.2|        2|            |         1.7|        0.8|       2|           |         Low|  Very High|
# |06/01/2011|  21|          0.6|         0.2|        2|            |         1.9|          1|       2|           |         Low|  Very High|
# |06/01/2011|  22|          0.6|         0.3|        2|            |         2.2|        1.3|       2|           |    Moderate|  Very High|
# |06/01/2011|  23|          0.7|         0.4|        2|            |         1.9|        1.4|       2|           |    Moderate|  Very High|
# |07/01/2011|   0|          0.6|         0.5|        2|            |         1.1|        1.4|       2|           |        High|  Very High|
# |07/01/2011|   1|          0.5|         0.5|        2|            |         1.7|        1.5|       2|           |        High|  Very High|
# |07/01/2011|   2|          0.4|         0.5|        2|            |         1.5|        1.6|       2|           |        High|  Very High|
# |07/01/2011|   3|          0.6|         0.6|        2|            |         1.5|        1.7|       2|           |        High|  Very High|
# |07/01/2011|   4|          0.5|         0.6|        2|            |         0.2|        1.5|       2|           |        High|  Very High|
# |07/01/2011|   5|          0.3|         0.5|        2|            |         0.1|        1.3|       2|           |        High|  Very High|
# |07/01/2011|   6|            0|         0.5|        2|            |         0.1|          1|       2|           |        High|  Very High|
# |07/01/2011|   7|            0|         0.4|        2|            |         0.1|        0.8|       2|           |    Moderate|  Very High|
# |07/01/2011|   8|            0|         0.3|        2|            |         0.2|        0.7|       2|           |    Moderate|  Very High|
# |07/01/2011|   9|          0.1|         0.2|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |07/01/2011|  10|          0.1|         0.2|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |07/01/2011|  11|          0.1|         0.1|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |07/01/2011|  12|          0.1|         0.1|        2|            |         0.4|        0.2|       2|           |         Low|        Low|
# |07/01/2011|  13|          0.1|           0|        2|            |         0.6|        0.3|       2|           |         Low|   Moderate|
# |07/01/2011|  14|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |07/01/2011|  15|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |07/01/2011|  16|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |07/01/2011|  17|          0.2|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |07/01/2011|  18|          0.2|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |07/01/2011|  19|          0.2|         0.1|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |07/01/2011|  20|          0.2|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |07/01/2011|  21|          0.2|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |07/01/2011|  22|          0.1|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |07/01/2011|  23|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |08/01/2011|   0|          0.1|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |08/01/2011|   1|            0|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |08/01/2011|   2|            0|         0.1|        2|            |         0.1|        0.3|       2|           |         Low|   Moderate|
# |08/01/2011|   3|            0|         0.1|        2|            |         0.1|        0.3|       2|           |         Low|   Moderate|
# |08/01/2011|   4|            0|         0.1|        2|            |           0|        0.2|       2|           |         Low|        Low|
# |08/01/2011|   5|            0|         0.1|        2|            |           0|        0.2|       2|           |         Low|        Low|
# |08/01/2011|   6|            0|           0|        2|            |         0.1|        0.1|       2|           |         Low|        Low|
# |08/01/2011|   7|            0|           0|        2|            |         0.1|        0.1|       2|           |         Low|        Low|
# |08/01/2011|   8|            0|           0|        2|            |         0.1|        0.1|       2|           |         Low|        Low|
# |08/01/2011|   9|            0|           0|        2|            |         0.2|        0.1|       2|           |         Low|        Low|
# |08/01/2011|  10|            0|           0|        2|            |         0.2|        0.1|       2|           |         Low|        Low|
# |08/01/2011|  11|            0|           0|        2|            |         0.2|        0.1|       2|           |         Low|        Low|
# |08/01/2011|  12|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  13|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  14|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  15|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  16|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  17|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  18|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  19|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  20|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  21|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  22|          0.1|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |08/01/2011|  23|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |09/01/2011|   0|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |09/01/2011|   1|            0|           0|        2|            |         0.1|        0.2|       2|           |         Low|        Low|
# |09/01/2011|   2|            0|           0|        2|            |         0.1|        0.2|       2|           |         Low|        Low|
# |09/01/2011|   3|            0|           0|        2|            |         0.1|        0.2|       2|           |         Low|        Low|
# |09/01/2011|   4|            0|           0|        2|            |         0.1|        0.2|       2|           |         Low|        Low|
# |09/01/2011|   5|            0|           0|        2|            |         0.1|        0.1|       2|           |         Low|        Low|
# |09/01/2011|   6|            0|           0|        2|            |         0.1|        0.1|       2|           |         Low|        Low|
# |09/01/2011|   7|            0|           0|        2|            |         0.1|        0.1|       2|           |         Low|        Low|
# |09/01/2011|   8|            0|           0|        2|            |         0.2|        0.1|       2|           |         Low|        Low|
# |09/01/2011|   9|            0|           0|        2|            |         0.2|        0.1|       2|           |         Low|        Low|
# |09/01/2011|  10|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |09/01/2011|  11|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |09/01/2011|  12|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |09/01/2011|  13|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |09/01/2011|  14|          0.1|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |09/01/2011|  15|          0.1|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |09/01/2011|  16|          0.1|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |09/01/2011|  17|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |09/01/2011|  18|          0.1|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |09/01/2011|  19|          0.2|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |09/01/2011|  20|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |09/01/2011|  21|          0.2|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |09/01/2011|  22|          0.2|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |09/01/2011|  23|          0.2|         0.2|        2|            |         0.4|        0.5|       2|           |         Low|       High|
# |10/01/2011|   0|          0.1|         0.1|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |10/01/2011|   1|            0|         0.1|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |10/01/2011|   2|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |10/01/2011|   3|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |10/01/2011|   4|            0|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |10/01/2011|   5|            0|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |10/01/2011|   6|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |10/01/2011|   7|          0.1|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |10/01/2011|   8|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |10/01/2011|   9|          0.1|           0|        2|            |         0.5|        0.3|       2|           |         Low|   Moderate|
# |10/01/2011|  10|          0.1|           0|        2|            |         0.8|        0.4|       2|           |         Low|   Moderate|
# |10/01/2011|  11|          0.3|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |10/01/2011|  12|          0.1|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |10/01/2011|  13|          0.1|         0.1|        2|            |         0.8|        0.5|       2|           |         Low|       High|
# |10/01/2011|  14|          0.1|         0.1|        2|            |         0.7|        0.6|       2|           |         Low|       High|
# |10/01/2011|  15|          0.2|         0.1|        2|            |         0.8|        0.6|       2|           |         Low|       High|
# |10/01/2011|  16|          0.1|         0.1|        2|            |         0.6|        0.7|       2|           |         Low|  Very High|
# |10/01/2011|  17|          0.3|         0.2|        2|            |         0.6|        0.7|       2|           |         Low|  Very High|
# |10/01/2011|  18|          0.2|         0.2|        2|            |         0.6|        0.7|       2|           |         Low|  Very High|
# |10/01/2011|  19|          0.1|         0.1|        2|            |         0.8|        0.7|       2|           |         Low|  Very High|
# |10/01/2011|  20|          0.1|         0.1|        2|            |         0.6|        0.7|       2|           |         Low|  Very High|
# |10/01/2011|  21|          0.1|         0.1|        2|            |         0.5|        0.6|       2|           |         Low|       High|
# |10/01/2011|  22|          0.1|         0.1|        2|            |         0.4|        0.6|       2|           |         Low|       High|
# |10/01/2011|  23|          0.1|         0.1|        2|            |         0.3|        0.6|       2|           |         Low|       High|
# |11/01/2011|   0|            0|         0.1|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |11/01/2011|   1|            0|         0.1|        2|            |         0.2|        0.5|       2|           |         Low|       High|
# |11/01/2011|   2|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |11/01/2011|   3|            0|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |11/01/2011|   4|            0|           0|        2|            |         0.1|        0.3|       2|           |         Low|   Moderate|
# |11/01/2011|   5|            0|           0|        2|            |         0.1|        0.2|       2|           |         Low|        Low|
# |11/01/2011|   6|            0|           0|        2|            |         0.1|        0.2|       2|           |         Low|        Low|
# |11/01/2011|   7|            0|           0|        2|            |         0.2|        0.2|       2|           |         Low|        Low|
# |11/01/2011|   8|            0|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |11/01/2011|   9|          0.1|           0|        2|            |         0.4|        0.2|       2|           |         Low|        Low|
# |11/01/2011|  10|          0.1|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |11/01/2011|  11|          0.1|           0|        2|            |         0.3|        0.2|       2|           |         Low|        Low|
# |11/01/2011|  12|          0.1|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |11/01/2011|  13|          0.1|         0.1|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |11/01/2011|  14|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |11/01/2011|  15|          0.1|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |11/01/2011|  16|          0.1|         0.1|        2|            |         0.7|        0.4|       2|           |         Low|   Moderate|
# |11/01/2011|  17|          0.3|         0.1|        2|            |         0.7|        0.4|       2|           |         Low|   Moderate|
# |11/01/2011|  18|          0.2|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |11/01/2011|  19|          0.2|         0.2|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |11/01/2011|  20|          0.2|         0.2|        2|            |         0.4|        0.5|       2|           |         Low|       High|
# |11/01/2011|  21|          0.1|         0.2|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |11/01/2011|  22|            0|         0.2|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |11/01/2011|  23|            0|         0.2|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |12/01/2011|   0|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |12/01/2011|   1|            0|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |12/01/2011|   2|            0|         0.1|        2|            |         0.2|        0.4|       2|           |         Low|   Moderate|
# |12/01/2011|   3|            0|         0.1|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|   4|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|   5|            0|           0|        2|            |         0.2|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|   6|            0|           0|        2|            |         0.3|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|   7|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|   8|          0.1|           0|        2|            |         0.5|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|   9|          0.1|           0|        2|            |         0.5|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|  10|          0.1|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |12/01/2011|  11|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |12/01/2011|  12|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |12/01/2011|  13|          0.1|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |12/01/2011|  14|          0.1|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |12/01/2011|  15|          0.1|         0.1|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |12/01/2011|  16|          0.1|         0.1|        2|            |         0.8|        0.5|       2|           |         Low|       High|
# |12/01/2011|  17|          0.2|         0.1|        2|            |         0.7|        0.6|       2|           |         Low|       High|
# |12/01/2011|  18|          0.2|         0.1|        2|            |         0.9|        0.6|       2|           |         Low|       High|
# |12/01/2011|  19|          0.3|         0.2|        2|            |         0.6|        0.6|       2|           |         Low|       High|
# |12/01/2011|  20|          0.2|         0.2|        2|            |         0.6|        0.6|       2|           |         Low|       High|
# |12/01/2011|  21|          0.1|         0.2|        2|            |         0.5|        0.6|       2|           |         Low|       High|
# |12/01/2011|  22|          0.1|         0.2|        2|            |         0.6|        0.6|       2|           |         Low|       High|
# |12/01/2011|  23|          0.1|         0.2|        2|            |         0.5|        0.6|       2|           |         Low|       High|
# |13/01/2011|   0|          0.1|         0.2|        2|            |         0.5|        0.6|       2|           |         Low|       High|
# |13/01/2011|   1|          0.1|         0.1|        2|            |         0.4|        0.6|       2|           |         Low|       High|
# |13/01/2011|   2|            0|         0.1|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |13/01/2011|   3|            0|         0.1|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |13/01/2011|   4|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |13/01/2011|   5|            0|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |13/01/2011|   6|            0|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |13/01/2011|   7|            0|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |13/01/2011|   8|          0.1|         0.1|        2|            |         0.5|        0.3|       2|           |         Low|   Moderate|
# |13/01/2011|   9|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |13/01/2011|  10|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |13/01/2011|  11|          0.1|         0.1|        2|            |         0.6|        0.4|       2|           |         Low|   Moderate|
# |13/01/2011|  12|          0.1|         0.1|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |13/01/2011|  13|          0.1|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |13/01/2011|  14|          0.1|         0.1|        2|            |         0.5|        0.5|       2|           |         Low|       High|
# |13/01/2011|  15|          0.1|         0.1|        2|            |         0.6|        0.5|       2|           |         Low|       High|
# |13/01/2011|  16|          0.1|         0.1|        2|            |         0.6|        0.6|       2|           |         Low|       High|
# |13/01/2011|  17|          0.2|         0.1|        2|            |         0.6|        0.6|       2|           |         Low|       High|
# |13/01/2011|  18|          0.2|         0.1|        2|            |         0.9|        0.6|       2|           |         Low|       High|
# |13/01/2011|  19|          0.3|         0.2|        2|            |         0.8|        0.7|       2|           |         Low|  Very High|
# |13/01/2011|  20|          0.2|         0.2|        2|            |         0.9|        0.7|       2|           |         Low|  Very High|
# |13/01/2011|  21|          0.2|         0.2|        2|            |         1.3|        0.8|       2|           |         Low|  Very High|
# |13/01/2011|  22|          0.3|         0.2|        2|            |         0.5|        0.8|       2|           |         Low|  Very High|
# |13/01/2011|  23|          0.1|         0.2|        2|            |         0.4|        0.8|       2|           |         Low|  Very High|
# |14/01/2011|   0|          0.1|         0.2|        2|            |         0.4|        0.7|       2|           |         Low|  Very High|
# |14/01/2011|   1|          0.1|         0.2|        2|            |         0.4|        0.7|       2|           |         Low|  Very High|
# |14/01/2011|   2|          0.1|         0.2|        2|            |         0.4|        0.6|       2|           |         Low|       High|
# |14/01/2011|   3|            0|         0.1|        2|            |         0.3|        0.6|       2|           |         Low|       High|
# |14/01/2011|   4|            0|         0.1|        2|            |         0.3|        0.5|       2|           |         Low|       High|
# |14/01/2011|   5|          0.1|         0.1|        2|            |         0.3|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|   6|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|   7|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |14/01/2011|   8|          0.1|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |14/01/2011|   9|            0|         0.1|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |14/01/2011|  10|            0|           0|        2|            |         0.4|        0.3|       2|           |         Low|   Moderate|
# |14/01/2011|  11|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  12|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  13|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  14|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  15|            0|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  16|          0.1|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  17|          0.1|           0|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  18|          0.1|           0|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  19|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  20|          0.1|         0.1|        2|            |         0.5|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  21|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  22|          0.1|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# |14/01/2011|  23|            0|         0.1|        2|            |         0.4|        0.4|       2|           |         Low|   Moderate|
# ...
# |24/12/2011|  13|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  14|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  15|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  16|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  17|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  18|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  19|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  20|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  21|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  22|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |24/12/2011|  23|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   0|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   1|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   2|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   3|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   4|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   5|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   6|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   7|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   8|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|   9|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  10|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  11|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  12|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  13|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  14|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  15|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  16|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  17|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  18|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  19|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  20|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  21|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  22|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |25/12/2011|  23|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   0|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   1|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   2|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   3|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   4|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   5|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   6|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   7|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   8|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|   9|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  10|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  11|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  12|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  13|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  14|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  15|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  16|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  17|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  18|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  19|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  20|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  21|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  22|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |26/12/2011|  23|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   0|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   1|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   2|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   3|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   4|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   5|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   6|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   7|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   8|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|   9|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  10|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  11|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  12|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  13|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  14|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  15|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  16|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  17|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  18|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  19|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  20|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  21|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  22|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |27/12/2011|  23|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   0|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   1|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   2|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   3|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   4|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   5|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   6|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   7|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   8|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|   9|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  10|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  11|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  12|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  13|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  14|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  15|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  16|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  17|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  18|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  19|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  20|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  21|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  22|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |28/12/2011|  23|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |29/12/2011|   0|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |29/12/2011|   1|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |29/12/2011|   2|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |29/12/2011|   3|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |29/12/2011|   4|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# |29/12/2011|   5|         NULL|        NULL|         |            |        NULL|       NULL|        |           |     Unknown|    Unknown|
# +----------+----+-------------+------------+---------+------------+------------+-----------+--------+-----------+------------+-----------+
# only showing top 8700 rows
